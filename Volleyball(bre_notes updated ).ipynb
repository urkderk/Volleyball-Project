# %% [markdown]
# <a href="https://colab.research.google.com/github/urkderk/Volleyball-Project/blob/main/Volleyball(bre_notes%20updated%20).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# try to do other code

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
vball=pd.read_csv("clean_data.csv")

# %% [markdown]
# Setter 1
#
# Outside Hitter is position 2
#
# Middle Blocker 3
#
# Opposite Hitter 4
#
# Libero is position 6

# %%
vball.drop(index=68,inplace=True)
vball.drop(index=212,inplace=True)
vball.drop(index=356,inplace=True)

# %%
#just to check zeros droped
vball[vball['spike']==0]
# Out:
# Empty DataFrame
# Columns: [index, name, date_of_birth, height, weight, spike, block, position_number, country]
# Index: []

# %%
vball_country = pd.Categorical(vball['country'])
print(vball_country)
# Out:
# [23, 23, 23, 23, 23, ..., 26, 26, 26, 26, 26]
# Length: 429
# Categories (12, int64): [5, 9, 10, 15, ..., 26, 29, 30, 31]

# %%
vball_position = pd.Categorical(vball['position_number'])
print(vball_position)
# Out:
# [3, 1, 2, 6, 1, ..., 2, 3, 1, 1, 3]
# Length: 429
# Categories (5, int64): [1, 2, 3, 4, 6]

# %%
sns.pairplot(vball)

# %%
#nozero=vball['spike']
#nozero.describe(exclude=)

# %%
outside = vball[vball['position_number']==2]
outside.describe()
# Out:
#             index      height      weight       spike       block  \
# count  144.000000  144.000000  144.000000  144.000000  144.000000
# mean   213.729167  179.916667   68.250000  286.041667  274.062500
# std    124.747982    7.831709    6.278501   32.486441   30.336163
# min      2.000000  160.000000   52.000000  178.000000  178.000000
# 25%    102.750000  176.500000   63.750000  285.000000  269.750000
# 50%    212.500000  181.000000   69.000000  296.000000  284.500000
# 75%    323.250000  186.000000   72.000000  304.250000  293.500000
# max    427.000000  195.000000   80.000000  322.000000  308.000000
#
#        position_number     country
# count            144.0  144.000000
# mean               2.0   20.145833
# std                0.0    8.465453
# min                2.0    5.000000
# 25%                2.0   13.750000
# 50%                2.0   23.000000
# 75%                2.0   29.000000
# max                2.0   31.000000

# %%
sns.lmplot(data=outside,x='height',y='spike')
plt.title('overall Spike vs Height')
# Out:
# Text(0.5, 1.0, 'overall Spike vs Height')

# %%
libero = vball[vball['position_number']==6]
sns.lmplot(data=libero,x='height',y='spike')
plt.title('Libero Spike vs Height')
# Out:
# Text(0.5, 1.0, 'Libero Spike vs Height')

# %%
sns.lmplot(data=outside,x='height',y='spike')
plt.title('Outside Hitter Spike vs Height')
# Out:
# Text(0.5, 1.0, 'Outside Hitter Spike vs Height')

# %%
outside = vball[vball['position_number']==2]
sns.lmplot(data=outside,x='height',y='block')
plt.title('Outside Hitter Block vs Height')
# Out:
# Text(0.5, 1.0, 'Outside Hitter Block vs Height')

# %%
sns.lmplot(data=libero,x='height',y='block')
plt.title('Libero Block vs Height')
# Out:
# Text(0.5, 1.0, 'Libero Block vs Height')

# %%
sns.lmplot(data=opposite,x='height',y='block')
plt.title('Opposite Hitter Block vs Height')
# Out:
# Text(0.5, 1.0, 'Opposite Hitter Block vs Height')

# %%
sns.lmplot(data=middle,x='height',y='block')
plt.title('Middle Blocker Block vs Height')
# Out:
# Text(0.5, 1.0, 'Middle Blocker Block vs Height')

# %%
sns.lmplot(data=setter,x='height',y='block')
plt.title('Setter Block vs Height')
# Out:
# Text(0.5, 1.0, 'Setter Block vs Height')

# %%
libero.describe()
# Out:
#            index      height     weight       spike       block  \
# count   41.00000   41.000000  41.000000   41.000000   41.000000
# mean   223.97561  171.268293  60.951220  271.756098  265.365854
# std    125.21651    5.549885   6.553439   22.308945   21.211737
# min      3.00000  162.000000  52.000000  198.000000  190.000000
# 25%    127.00000  167.000000  56.000000  260.000000  255.000000
# 50%    230.00000  171.000000  60.000000  275.000000  272.000000
# 75%    334.00000  176.000000  64.000000  285.000000  278.000000
# max    422.00000  180.000000  78.000000  302.000000  290.000000
#
#        position_number    country
# count             41.0  41.000000
# mean               6.0  18.634146
# std                0.0   8.578333
# min                6.0   5.000000
# 25%                6.0  10.000000
# 50%                6.0  23.000000
# 75%                6.0  26.000000
# max                6.0  30.000000

# %% [markdown]
# take out cant block or leave and explain

# %%
vball.drop(index=60,inplace=True)
vball.drop(index=204,inplace=True)
vball.drop(index=348,inplace=True)

# %%
setter= vball[vball['position_number']==1]
setter.describe()
# Out:
#            index      height     weight       spike       block  \
# count   75.00000   75.000000  75.000000   75.000000   75.000000
# mean   217.72000  176.880000  67.840000  285.840000  274.440000
# std    125.95608    6.859517   5.122921   21.653313   20.749627
# min      1.00000  153.000000  55.000000  200.000000  210.000000
# 25%    111.50000  174.000000  65.000000  280.000000  272.000000
# 50%    224.00000  180.000000  69.000000  287.000000  280.000000
# 75%    323.00000  182.000000  71.000000  297.000000  284.000000
# max    430.00000  184.000000  75.000000  320.000000  310.000000
#
#        position_number    country
# count             75.0  75.000000
# mean               1.0  20.000000
# std                0.0   8.394013
# min                1.0   5.000000
# 25%                1.0  15.000000
# 50%                1.0  23.000000
# 75%                1.0  26.000000
# max                1.0  31.000000

# %%
middle= vball[vball['position_number']==3]
middle.describe()
# Out:
#             index      height      weight       spike       block  \
# count  108.000000  108.000000  108.000000  108.000000  108.000000
# mean   213.472222  186.888889   71.694444  297.000000  285.333333
# std    125.684627    5.229916    7.347780   11.766418   14.079215
# min      0.000000  176.000000   60.000000  270.000000  246.000000
# 25%    107.000000  184.000000   66.750000  290.000000  279.750000
# 50%    214.000000  186.000000   70.000000  295.500000  285.000000
# 75%    316.250000  190.500000   76.500000  305.000000  297.000000
# max    431.000000  199.000000   87.000000  320.000000  305.000000
#
#        position_number     country
# count            108.0  108.000000
# mean               3.0   19.166667
# std                0.0    8.383896
# min                3.0    5.000000
# 25%                3.0   10.000000
# 50%                3.0   19.000000
# 75%                3.0   26.000000
# max                3.0   31.000000

# %%
opposite = vball[vball['position_number']==4]
sns.lmplot(data=opposite,x='height',y='spike')
plt.title('Opposite Hitter Spike vs Height')
# Out:
# Text(0.5, 1.0, 'Opposite Hitter Spike vs Height')

# %%
middle= vball[vball['position_number']==3]
sns.lmplot(data=middle,x='height',y='spike')
plt.title('Middle Blockers Spike vs Height')

# %%
setter= vball[vball['position_number']==1]
sns.lmplot(data=setter,x='height',y='spike')
plt.title('Setter Spike vs Height')
# Out:
# Text(0.5, 1.0, 'Setter Spike vs Height')
